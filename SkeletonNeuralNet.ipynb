# %%
import os, shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
torch.__version__
# Out:
# '1.8.1'

# %%
USE_CUDA    = torch.cuda.is_available()
DEVICE      = torch.device("cuda" if USE_CUDA else "cpu")
EPOCHS      = 300
BATCH_SIZE  = 1460

# %%
sample = pd.read_csv("data/coin_Bitcoin_Full.csv")
sample.drop(['Tommorow_Close','Tommorow_IncRatio','Tommorow_Pos'],axis='columns')
# Out:
#             Date          High           Low          Open         Close  \
# 0     2017-01-01   1003.080017    958.698975    963.658020    998.325012
# 1     2017-01-02   1031.390015    996.702026    998.617004   1021.750000
# 2     2017-01-03   1044.079956   1021.599976   1021.599976   1043.839966
# 3     2017-01-04   1159.420044   1044.400024   1044.400024   1154.729980
# 4     2017-01-05   1191.099976    910.416992   1156.729980   1013.380005
# ...          ...           ...           ...           ...           ...
# 1455  2020-12-26  26718.070893  24522.689482  24677.016056  26437.037509
# 1456  2020-12-27  28288.840022  25922.769765  26439.373289  26272.294567
# 1457  2020-12-28  27389.112064  26207.639931  26280.821415  27084.807886
# 1458  2020-12-29  27370.720084  25987.298075  27081.809729  27362.436557
# 1459  2020-12-30  28937.740004  27360.089709  27360.089709  28840.953420
#
#             Volume         MA200        EMA130  PercentB20     RSI14  \
# 0     1.477750e+08    676.439377    726.854930    0.896990  0.859802
# 1     2.221850e+08    677.716587    731.357145    0.913535  0.869408
# 2     1.851680e+08    679.191241    736.127876    0.921943  0.875023
# 3     3.449460e+08    681.183756    742.518748    1.098171  0.899147
# 4     5.101990e+08    682.431751    746.654034    0.722185  0.645207
# ...            ...           ...           ...         ...       ...
# 1455  4.833265e+10  12929.903141  15766.746562    0.976863  0.851761
# 1456  6.647990e+10  13011.914142  15927.136608    0.903582  0.833914
# 1457  4.905674e+10  13100.729275  16097.482734    0.919669  0.844247
# 1458  4.526595e+10  13190.137239  16269.466762    0.894310  0.845700
# 1459  5.128744e+10  13286.965619  16461.397856    0.955826  0.839918
#
#          MFI14         MACD    fast_k    slow_d
# 0     0.789506   -73.609344  0.977651  0.934168
# 1     0.805343   -76.362399  0.959815  0.951889
# 2     0.814751   -79.333322  0.999019  0.978828
# 3     0.833259   -84.066016  0.985581  0.981472
# 4     0.673515   -86.055164  0.459285  0.814628
# ...        ...          ...       ...       ...
# 1455  0.920118 -2997.597949  0.964799  0.962039
# 1456  0.927265 -3083.370200  0.782609  0.913536
# 1457  0.931462 -3177.755257  0.869255  0.872221
# 1458  0.934446 -3270.925280  0.896958  0.849607
# 1459  0.936562 -3383.930625  0.987435  0.917883
#
# [1460 rows x 14 columns]

# %%
from datetime import datetime
# make train_loader and test_loader
sample = sample[['Date', 'High', 'Low', 'Open', 'Close', 'Volume','MA200','EMA130','PercentB20','RSI14','MFI14','MACD','fast_k','slow_d']]
sample['Label'] = ""
sample['Up']= np.nan
sample['Down'] = np.nan
for idx in sample.index:
    # no information for the last day
    if idx == sample.index[-1]:
        continue
    
    if sample.shift(-1).loc[idx, 'Close'] > sample.shift(-1).loc[idx, 'Open']:
        sample.loc[idx, 'Label'] = "UP" 
        sample.loc[idx, 'Up'] = 1
        sample.loc[idx, 'Down'] = 0. 
    else:
        sample.loc[idx, 'Label'] = "DOWN" 
        sample.loc[idx, 'Up'] = 0.
        sample.loc[idx, 'Down'] = 1.
    date = sample.loc[idx, 'Date']
    sample.loc[idx, 'Date'] = datetime.strptime(date, '%Y-%m-%d').date()
sample = sample.set_index('Date')
sample.tail()
# Out:
#                     High           Low          Open         Close  \
# Date
# 2020-12-26  26718.070893  24522.689482  24677.016056  26437.037509
# 2020-12-27  28288.840022  25922.769765  26439.373289  26272.294567
# 2020-12-28  27389.112064  26207.639931  26280.821415  27084.807886
# 2020-12-29  27370.720084  25987.298075  27081.809729  27362.436557
# 2020-12-30  28937.740004  27360.089709  27360.089709  28840.953420
#
#                   Volume         MA200        EMA130  PercentB20     RSI14  \
# Date
# 2020-12-26  4.833265e+10  12929.903141  15766.746562    0.976863  0.851761
# 2020-12-27  6.647990e+10  13011.914142  15927.136608    0.903582  0.833914
# 2020-12-28  4.905674e+10  13100.729275  16097.482734    0.919669  0.844247
# 2020-12-29  4.526595e+10  13190.137239  16269.466762    0.894310  0.845700
# 2020-12-30  5.128744e+10  13286.965619  16461.397856    0.955826  0.839918
#
#                MFI14         MACD    fast_k    slow_d Label   Up  Down
# Date
# 2020-12-26  0.920118 -2997.597949  0.964799  0.962039  DOWN  0.0   1.0
# 2020-12-27  0.927265 -3083.370200  0.782609  0.913536    UP  1.0   0.0
# 2020-12-28  0.931462 -3177.755257  0.869255  0.872221    UP  1.0   0.0
# 2020-12-29  0.934446 -3270.925280  0.896958  0.849607    UP  1.0   0.0
# 2020-12-30  0.936562 -3383.930625  0.987435  0.917883        NaN   NaN

# %%
start_date = datetime.strptime('2017-01-01', '%Y-%m-%d').date()
end_date = datetime.strptime('2020-12-29', '%Y-%m-%d').date()
cut_date1 = datetime.strptime('2019-12-31', '%Y-%m-%d').date()
cut_date2 = datetime.strptime('2020-01-01', '%Y-%m-%d').date()

train_df = sample[start_date : cut_date1]
test_df = sample[cut_date2 :end_date]

# %%
X_features = ["High", "Low", "Open", "Close", "Volume",'MA200','EMA130','PercentB20','RSI14','MFI14','MACD','fast_k','slow_d']
Y_feature = ["Up"]

train_X_df, train_Y_df = train_df[X_features], train_df[Y_feature]
test_X_df, test_Y_df = test_df[X_features], test_df[Y_feature]

# %%
train_X = torch.from_numpy(train_X_df.astype('float64').to_numpy())
train_Y = torch.from_numpy(train_Y_df.astype('float64').to_numpy()).squeeze()
test_X = torch.from_numpy(test_X_df.astype('float64').to_numpy())
test_Y = torch.from_numpy(test_Y_df.astype('float64').to_numpy()).squeeze()

print(train_Y)
# Out:
# tensor([1., 1., 1.,  ..., 0., 0., 1.], dtype=torch.float64)

# %%
train = data_utils.TensorDataset(train_X, train_Y)
train_loader = data_utils.DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)

test = data_utils.TensorDataset(test_X, test_Y)
test_loader = data_utils.DataLoader(test, batch_size=BATCH_SIZE, shuffle=False)

# %%
class NeuralNet(nn.Module):
    def __init__(self, n_features, n_output=2):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(n_features, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 128)
        self.fc5 = nn.Linear(128, 64)
        self.fc6 = nn.Linear(64, n_output)

    def forward(self, x):
      x = F.relu(self.fc1(x))
      x = F.dropout(x)

      x = F.relu(self.fc2(x))
      x = F.dropout(x)

      x = F.relu(self.fc3(x))
      x = F.dropout(x)

      x = F.relu(self.fc4(x))
      x = F.dropout(x)
    
      x = F.relu(self.fc5(x))
      x = F.dropout(x)
    
      x = self.fc6(x)
      return x

# %%
# change n_features and n_output with respect to the tensor shape
model = NeuralNet(n_features=13, n_output=2).to(DEVICE)
optimizer = optim.Adadelta(model.parameters(), lr=0.1)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.05)

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    train_loss = 0.
    correct = 0.
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data.float())
        loss = F.cross_entropy(output, target.long())
        loss.backward()
        optimizer.step()

        # get train_loss and train_accuracy
        train_loss += F.cross_entropy(output, target.long(), reduction='sum').item()
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(target.view_as(pred)).sum().item()
    train_loss /= len(train_loader.dataset)
    train_accuracy = 100.* correct/len(train_loader.dataset)
    return train_loss, train_accuracy

def evaluate(model, test_loader):
    # assume classification
    model.eval()
    test_loss = 0.
    correct = 0.
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data.float())
            test_loss += F.cross_entropy(output, target.long(), reduction='sum').item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100.* correct/len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
# train
history = dict()
history['train_loss'] = list()
history['train_acc'] = list()
history['test_loss'] = list()
history['test_acc'] = list()

for epoch in range(1, EPOCHS+1):
    train_loss, train_acc = train(model, train_loader, optimizer, epoch=1)
    test_loss, test_acc = evaluate(model, test_loader)
    scheduler.step()
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)
    history['test_loss'].append(test_loss)
    history['test_acc'].append(test_acc)
    print(f"[{epoch}] Train Loss: {round(train_loss, 4)}, Train Accuracy: {round(train_acc, 2)}")
    print(f"[{epoch}] Test Loss : {round(test_loss, 4)}, Test Accuracy : {round(test_acc, 2)}\n")
# Out:
# [120] Train Loss: 16208289.0813, Train Accuracy: 53.88
# [120] Test Loss : 69465493.0989, Test Accuracy : 51.37
#
# [121] Train Loss: 17060242.1187, Train Accuracy: 50.78
# [121] Test Loss : 73469991.3846, Test Accuracy : 48.08
#
# [122] Train Loss: 19098703.4886, Train Accuracy: 50.78
# [122] Test Loss : 88512067.5165, Test Accuracy : 47.53
#
# [123] Train Loss: 20038563.4192, Train Accuracy: 49.32
# [123] Test Loss : 77580614.3297, Test Accuracy : 46.98
#
# [124] Train Loss: 18495033.5123, Train Accuracy: 50.23
# [124] Test Loss : 81952604.8352, Test Accuracy : 50.82
#
# [125] Train Loss: 19760635.7918, Train Accuracy: 49.41
# [125] Test Loss : 72624341.8022, Test Accuracy : 51.1
#
# [126] Train Loss: 17579893.5963, Train Accuracy: 49.68
# [126] Test Loss : 70725519.4725, Test Accuracy : 48.63
#
# [127] Train Loss: 18884946.5279, Train Accuracy: 49.04
# [127] Test Loss : 71629233.2308, Test Accuracy : 53.85
#
# [128] Train Loss: 18982378.9589, Train Accuracy: 48.49
# [128] Test Loss : 81184638.5934, Test Accuracy : 50.0
#
# [129] Train Loss: 18902306.8347, Train Accuracy: 48.58
# [129] Test Loss : 74950374.6813, Test Accuracy : 50.0
#
# [130] Train Loss: 18967612.7854, Train Accuracy: 50.68
# [130] Test Loss : 64683975.7363, Test Accuracy : 53.57
#
# [131] Train Loss: 18166072.3434, Train Accuracy: 48.58
# [131] Test Loss : 75451189.4505, Test Accuracy : 51.37
#
# [132] Train Loss: 18044432.3653, Train Accuracy: 51.14
# [132] Test Loss : 72691498.1978, Test Accuracy : 48.63
#
# [133] Train Loss: 18247294.7142, Train Accuracy: 51.6
# [133] Test Loss : 78801706.1978, Test Accuracy : 51.1
#
# [134] Train Loss: 18431382.7945, Train Accuracy: 49.22
# [134] Test Loss : 72646042.7253, Test Accuracy : 51.1
#
# [135] Train Loss: 19357419.1927, Train Accuracy: 47.67
# [135] Test Loss : 77196288.0, Test Accuracy : 47.25
#
# [136] Train Loss: 15830649.1032, Train Accuracy: 54.16
# [136] Test Loss : 64448376.967, Test Accuracy : 53.85
#
# [137] Train Loss: 18287003.4703, Train Accuracy: 50.96
# [137] Test Loss : 79309660.8352, Test Accuracy : 46.98
#
# [138] Train Loss: 19578128.1315, Train Accuracy: 50.23
# [138] Test Loss : 74833981.8901, Test Accuracy : 51.37
#
# [139] Train Loss: 18668058.6521, Train Accuracy: 49.5
# [139] Test Loss : 67173336.6154, Test Accuracy : 48.63
#
# [140] Train Loss: 19849244.0548, Train Accuracy: 52.05
# [140] Test Loss : 83833687.2088, Test Accuracy : 46.43
#
# [141] Train Loss: 19022315.8941, Train Accuracy: 50.14
# [141] Test Loss : 81207447.9121, Test Accuracy : 43.41
#
# [142] Train Loss: 19588448.5553, Train Accuracy: 49.13
# [142] Test Loss : 69529650.6374, Test Accuracy : 53.02
#
# [143] Train Loss: 19489375.8539, Train Accuracy: 50.23
# [143] Test Loss : 74054644.7473, Test Accuracy : 51.92
#
# [144] Train Loss: 20048446.1881, Train Accuracy: 48.13
# [144] Test Loss : 62954951.7363, Test Accuracy : 53.02
#
# [145] Train Loss: 20304593.9434, Train Accuracy: 49.95
# [145] Test Loss : 60491494.6813, Test Accuracy : 55.22
#
# [146] Train Loss: 18419180.8292, Train Accuracy: 50.96
# [146] Test Loss : 71180046.0659, Test Accuracy : 52.2
#
# [147] Train Loss: 15997799.5689, Train Accuracy: 52.79
# [147] Test Loss : 70197231.1209, Test Accuracy : 47.8
#
# [148] Train Loss: 19319416.168, Train Accuracy: 50.23
# [148] Test Loss : 73449674.5495, Test Accuracy : 50.82
#
# [149] Train Loss: 17114395.3534, Train Accuracy: 51.96
# [149] Test Loss : 60103927.5604, Test Accuracy : 52.2
#
# [150] Train Loss: 17530928.6283, Train Accuracy: 52.6
# [150] Test Loss : 62046663.7363, Test Accuracy : 51.92
#
# [151] Train Loss: 17272394.3452, Train Accuracy: 50.32
# [151] Test Loss : 58002195.6923, Test Accuracy : 54.67
#
# [152] Train Loss: 19100904.8548, Train Accuracy: 49.13
# [152] Test Loss : 68466862.4176, Test Accuracy : 51.37
#
# [153] Train Loss: 19256646.3708, Train Accuracy: 49.77
# [153] Test Loss : 79257622.5055, Test Accuracy : 47.25
#
# [154] Train Loss: 20528964.968, Train Accuracy: 47.49
# [154] Test Loss : 72310947.1648, Test Accuracy : 48.08
#
# [155] Train Loss: 18602386.1187, Train Accuracy: 51.05
# [155] Test Loss : 83336079.4725, Test Accuracy : 47.25
#
# [156] Train Loss: 16470700.537, Train Accuracy: 50.96
# [156] Test Loss : 64162388.3956, Test Accuracy : 50.0
#
# [157] Train Loss: 18071847.5105, Train Accuracy: 50.87
# [157] Test Loss : 80304836.9231, Test Accuracy : 48.08
#
# [158] Train Loss: 19118994.5863, Train Accuracy: 50.05
# [158] Test Loss : 83334340.9231, Test Accuracy : 46.7
#
# [159] Train Loss: 18362356.7781, Train Accuracy: 48.95
# [159] Test Loss : 82945772.3077, Test Accuracy : 50.55
#
# [160] Train Loss: 19590642.4402, Train Accuracy: 49.59
# [160] Test Loss : 63491578.3736, Test Accuracy : 53.57
#
# [161] Train Loss: 17140592.9205, Train Accuracy: 53.42
# [161] Test Loss : 75686754.4615, Test Accuracy : 54.67
#
# [162] Train Loss: 17464601.4831, Train Accuracy: 52.6
# [162] Test Loss : 76149377.4066, Test Accuracy : 51.65
#
# [163] Train Loss: 19623580.6393, Train Accuracy: 50.32
# [163] Test Loss : 79176597.0989, Test Accuracy : 46.15
#
# [164] Train Loss: 18050202.3014, Train Accuracy: 47.95
# [164] Test Loss : 73693572.2198, Test Accuracy : 46.43
#
# [165] Train Loss: 18638851.7406, Train Accuracy: 50.23
# [165] Test Loss : 81405130.5495, Test Accuracy : 49.45
#
# [166] Train Loss: 18227660.0986, Train Accuracy: 51.05
# [166] Test Loss : 69542276.2198, Test Accuracy : 51.92
#
# [167] Train Loss: 19922182.7799, Train Accuracy: 48.58
# [167] Test Loss : 90054526.5934, Test Accuracy : 49.73
#
# [168] Train Loss: 19543566.495, Train Accuracy: 48.49
# [168] Test Loss : 73075813.2747, Test Accuracy : 52.75
#
# [169] Train Loss: 19844964.7635, Train Accuracy: 49.59
# [169] Test Loss : 74182785.4066, Test Accuracy : 48.63
#
# [170] Train Loss: 18189161.4393, Train Accuracy: 50.41
# [170] Test Loss : 82498976.3516, Test Accuracy : 44.51
#
# [171] Train Loss: 18673721.9799, Train Accuracy: 47.76
# [171] Test Loss : 68547927.2088, Test Accuracy : 52.75
#
# [172] Train Loss: 18220977.4466, Train Accuracy: 50.59
# [172] Test Loss : 81074586.7253, Test Accuracy : 52.2
#
# [173] Train Loss: 20987778.6886, Train Accuracy: 46.21
# [173] Test Loss : 82204323.1648, Test Accuracy : 49.73
#
# [174] Train Loss: 17808947.9014, Train Accuracy: 51.6
# [174] Test Loss : 66338540.3077, Test Accuracy : 51.92
#
# [175] Train Loss: 17595159.1452, Train Accuracy: 51.96
# [175] Test Loss : 60457297.5824, Test Accuracy : 54.12
#
# [176] Train Loss: 18830944.789, Train Accuracy: 48.4
# [176] Test Loss : 63074844.1319, Test Accuracy : 54.95
#
# [177] Train Loss: 22154558.8895, Train Accuracy: 47.67
# [177] Test Loss : 71496574.5934, Test Accuracy : 52.75
#
# [178] Train Loss: 20409242.0676, Train Accuracy: 48.68
# [178] Test Loss : 68761667.5165, Test Accuracy : 49.18
#
# [179] Train Loss: 21268648.3288, Train Accuracy: 47.03
# [179] Test Loss : 72783872.0, Test Accuracy : 46.15
#
# [180] Train Loss: 17749617.6219, Train Accuracy: 49.68
# [180] Test Loss : 70362331.4286, Test Accuracy : 46.7
#
# [181] Train Loss: 18238608.9498, Train Accuracy: 51.05
# [181] Test Loss : 65581849.3187, Test Accuracy : 51.92
#
# [182] Train Loss: 17313612.4493, Train Accuracy: 52.24
# [182] Test Loss : 66674474.1978, Test Accuracy : 51.92
#
# [183] Train Loss: 18607763.2877, Train Accuracy: 52.51
# [183] Test Loss : 78151837.5385, Test Accuracy : 47.25
#
# [184] Train Loss: 18451352.1973, Train Accuracy: 48.13
# [184] Test Loss : 58959314.989, Test Accuracy : 50.27
#
# [185] Train Loss: 17957123.9744, Train Accuracy: 53.33
# [185] Test Loss : 68721652.7473, Test Accuracy : 54.95
#
# [186] Train Loss: 16790040.7817, Train Accuracy: 52.33
# [186] Test Loss : 77324833.7582, Test Accuracy : 48.63
#
# [187] Train Loss: 17448804.7635, Train Accuracy: 51.51
# [187] Test Loss : 82173878.8571, Test Accuracy : 47.25
#
# [188] Train Loss: 18996166.9553, Train Accuracy: 48.4
# [188] Test Loss : 76769673.8462, Test Accuracy : 48.35
#
# [189] Train Loss: 19407078.0493, Train Accuracy: 49.41
# [189] Test Loss : 75259628.3077, Test Accuracy : 49.18
#
# [190] Train Loss: 18507704.9279, Train Accuracy: 49.13
# [190] Test Loss : 78913862.3297, Test Accuracy : 42.58
#
# [191] Train Loss: 19047617.5781, Train Accuracy: 50.78
# [191] Test Loss : 78547090.2857, Test Accuracy : 49.18
#
# [192] Train Loss: 18068658.6155, Train Accuracy: 50.05
# [192] Test Loss : 75432926.2418, Test Accuracy : 50.82
#
# [193] Train Loss: 18086099.3461, Train Accuracy: 49.04
# [193] Test Loss : 80356228.2198, Test Accuracy : 48.08
#
# [194] Train Loss: 19002193.1251, Train Accuracy: 50.59
# [194] Test Loss : 79488838.3297, Test Accuracy : 46.7
#
# [195] Train Loss: 18563638.7068, Train Accuracy: 50.78
# [195] Test Loss : 68530918.6813, Test Accuracy : 53.3
#
# [196] Train Loss: 17868906.6082, Train Accuracy: 52.88
# [196] Test Loss : 65103466.9011, Test Accuracy : 49.73
#
# [197] Train Loss: 19676708.9388, Train Accuracy: 50.68
# [197] Test Loss : 78224367.1209, Test Accuracy : 49.45
#
# [198] Train Loss: 19329123.1269, Train Accuracy: 49.68
# [198] Test Loss : 64299171.1648, Test Accuracy : 52.47
#
# [199] Train Loss: 17611797.5087, Train Accuracy: 51.69
# [199] Test Loss : 66901644.6593, Test Accuracy : 51.1
#
# [200] Train Loss: 18273815.8466, Train Accuracy: 50.59
# [200] Test Loss : 91363395.5165, Test Accuracy : 45.33
#
# [201] Train Loss: 19883598.0858, Train Accuracy: 49.68
# [201] Test Loss : 65027387.0769, Test Accuracy : 55.77
#
# [202] Train Loss: 21586972.99, Train Accuracy: 48.22
# [202] Test Loss : 77081892.5714, Test Accuracy : 49.18
#
# [203] Train Loss: 18499971.1562, Train Accuracy: 51.32
# [203] Test Loss : 78051530.5495, Test Accuracy : 47.8
#
# [204] Train Loss: 19545044.0475, Train Accuracy: 49.13
# [204] Test Loss : 76147588.2198, Test Accuracy : 47.25
#
# [205] Train Loss: 18948462.5826, Train Accuracy: 50.68
# [205] Test Loss : 78397805.7143, Test Accuracy : 47.8
#
# [206] Train Loss: 18338383.021, Train Accuracy: 52.24
# [206] Test Loss : 71606075.0769, Test Accuracy : 52.47
#
# [207] Train Loss: 19764935.6566, Train Accuracy: 50.78
# [207] Test Loss : 64130998.8571, Test Accuracy : 54.12
#
# [208] Train Loss: 17889424.0146, Train Accuracy: 49.77
# [208] Test Loss : 76125020.8352, Test Accuracy : 45.88
#
# [209] Train Loss: 21086247.2767, Train Accuracy: 48.4
# [209] Test Loss : 71693086.9451, Test Accuracy : 48.35
#
# [210] Train Loss: 18044174.2612, Train Accuracy: 52.6
# [210] Test Loss : 74384232.0879, Test Accuracy : 50.27
#
# [211] Train Loss: 18248875.1342, Train Accuracy: 49.86
# [211] Test Loss : 72732840.7912, Test Accuracy : 51.1
#
# [212] Train Loss: 19504950.0055, Train Accuracy: 49.32
# [212] Test Loss : 70780680.4396, Test Accuracy : 48.08
#
# [213] Train Loss: 17797151.7954, Train Accuracy: 50.32
# [213] Test Loss : 73437808.5275, Test Accuracy : 52.75
#
# [214] Train Loss: 19645392.3068, Train Accuracy: 51.05
# [214] Test Loss : 66983890.989, Test Accuracy : 54.67
#
# [215] Train Loss: 19658817.4612, Train Accuracy: 48.31
# [215] Test Loss : 74467249.2308, Test Accuracy : 49.45
#
# [216] Train Loss: 18460324.1205, Train Accuracy: 51.42
# [216] Test Loss : 69948050.2857, Test Accuracy : 50.82
#
# [217] Train Loss: 18706817.2858, Train Accuracy: 49.95
# [217] Test Loss : 70318952.0879, Test Accuracy : 52.75
#
# [218] Train Loss: 19413955.2146, Train Accuracy: 48.49
# [218] Test Loss : 81974727.7363, Test Accuracy : 48.08
#
# [219] Train Loss: 19102965.947, Train Accuracy: 49.04
# [219] Test Loss : 76127653.978, Test Accuracy : 45.6
#
# [220] Train Loss: 19748942.5534, Train Accuracy: 50.14
# [220] Test Loss : 69581238.8571, Test Accuracy : 50.27
#
# [221] Train Loss: 17441467.4995, Train Accuracy: 52.79
# [221] Test Loss : 68696041.4945, Test Accuracy : 51.1
#
# [222] Train Loss: 20061201.768, Train Accuracy: 49.04
# [222] Test Loss : 72290388.3956, Test Accuracy : 48.63
#
# [223] Train Loss: 16875424.6137, Train Accuracy: 51.23
# [223] Test Loss : 71973516.6593, Test Accuracy : 51.1
#
# [224] Train Loss: 17868867.3315, Train Accuracy: 51.42
# [224] Test Loss : 64789121.4066, Test Accuracy : 54.95
#
# [225] Train Loss: 19705042.411, Train Accuracy: 50.41
# [225] Test Loss : 65956222.5934, Test Accuracy : 51.1
#
# [226] Train Loss: 18578201.0155, Train Accuracy: 49.41
# [226] Test Loss : 65896166.6813, Test Accuracy : 52.47
#
# [227] Train Loss: 18714663.2767, Train Accuracy: 51.42
# [227] Test Loss : 69977616.8791, Test Accuracy : 50.55
#
# [228] Train Loss: 17334367.3863, Train Accuracy: 49.86
# [228] Test Loss : 80254812.8352, Test Accuracy : 50.27
#
# [229] Train Loss: 17359588.6466, Train Accuracy: 51.05
# [229] Test Loss : 76634933.4505, Test Accuracy : 51.65
#
# [230] Train Loss: 16408314.1553, Train Accuracy: 52.88
# [230] Test Loss : 55561396.044, Test Accuracy : 54.12
#
# [231] Train Loss: 17549592.5479, Train Accuracy: 49.5
# [231] Test Loss : 75083500.3077, Test Accuracy : 48.08
#
# [232] Train Loss: 18556245.3333, Train Accuracy: 51.23
# [232] Test Loss : 74082557.1868, Test Accuracy : 49.73
#
# [233] Train Loss: 18016807.7443, Train Accuracy: 51.14
# [233] Test Loss : 75316314.022, Test Accuracy : 48.63
#
# [234] Train Loss: 18201277.3699, Train Accuracy: 50.59
# [234] Test Loss : 76534350.7692, Test Accuracy : 48.35
#
# [235] Train Loss: 16134243.1269, Train Accuracy: 50.78
# [235] Test Loss : 75418404.5714, Test Accuracy : 50.0
#
# [236] Train Loss: 17087041.9288, Train Accuracy: 50.32
# [236] Test Loss : 73320509.8901, Test Accuracy : 51.1
#
# [237] Train Loss: 17631420.9023, Train Accuracy: 50.32
# [237] Test Loss : 76726255.1209, Test Accuracy : 50.82
#
# [238] Train Loss: 18625046.9114, Train Accuracy: 53.61
# [238] Test Loss : 66343215.8242, Test Accuracy : 49.45
#
# [239] Train Loss: 18472537.3078, Train Accuracy: 49.22
# [239] Test Loss : 65859893.4505, Test Accuracy : 49.45
#
# [240] Train Loss: 19493466.2429, Train Accuracy: 50.68
# [240] Test Loss : 67775544.2637, Test Accuracy : 50.0
#
# [241] Train Loss: 19789934.3489, Train Accuracy: 48.68
# [241] Test Loss : 74176860.8352, Test Accuracy : 56.04
#
# [242] Train Loss: 19828064.5553, Train Accuracy: 50.05
# [242] Test Loss : 64080800.3516, Test Accuracy : 51.92
#
# [243] Train Loss: 19239241.1763, Train Accuracy: 52.88
# [243] Test Loss : 72207011.1648, Test Accuracy : 48.35
#
# [244] Train Loss: 20235410.8201, Train Accuracy: 50.14
# [244] Test Loss : 75956105.8462, Test Accuracy : 49.45
#
# [245] Train Loss: 17835016.4164, Train Accuracy: 52.69
# [245] Test Loss : 74048320.7033, Test Accuracy : 52.2
#
# [246] Train Loss: 18456877.1215, Train Accuracy: 50.14
# [246] Test Loss : 80376708.2198, Test Accuracy : 49.18
#
# [247] Train Loss: 18853326.9041, Train Accuracy: 49.5
# [247] Test Loss : 75415332.5714, Test Accuracy : 51.37
#
# [248] Train Loss: 18343687.2475, Train Accuracy: 51.96
# [248] Test Loss : 63673169.5824, Test Accuracy : 52.75
#
# [249] Train Loss: 20886701.0046, Train Accuracy: 48.68
# [249] Test Loss : 73216163.1648, Test Accuracy : 50.27
#
# [250] Train Loss: 18362796.3032, Train Accuracy: 49.32
# [250] Test Loss : 73206165.0989, Test Accuracy : 51.92
#
# [251] Train Loss: 19345226.579, Train Accuracy: 50.78
# [251] Test Loss : 71766370.4615, Test Accuracy : 52.47
#
# [252] Train Loss: 17382393.4539, Train Accuracy: 51.42
# [252] Test Loss : 71545028.9231, Test Accuracy : 47.8
#
# [253] Train Loss: 20172562.4694, Train Accuracy: 51.23
# [253] Test Loss : 67927799.5604, Test Accuracy : 53.3
#
# [254] Train Loss: 19542917.4941, Train Accuracy: 50.68
# [254] Test Loss : 76721967.8242, Test Accuracy : 50.82
#
# [255] Train Loss: 19817368.1973, Train Accuracy: 52.33
# [255] Test Loss : 73435535.4725, Test Accuracy : 51.37
#
# [256] Train Loss: 16540057.6, Train Accuracy: 52.79
# [256] Test Loss : 71547960.2637, Test Accuracy : 51.37
#
# [257] Train Loss: 18145910.2977, Train Accuracy: 49.59
# [257] Test Loss : 77818756.2198, Test Accuracy : 47.53
#
# [258] Train Loss: 17246187.4265, Train Accuracy: 51.32
# [258] Test Loss : 78489020.4835, Test Accuracy : 46.15
#
# [259] Train Loss: 17524418.0457, Train Accuracy: 50.78
# [259] Test Loss : 68709949.8901, Test Accuracy : 53.85
#
# [260] Train Loss: 19632247.7005, Train Accuracy: 48.31
# [260] Test Loss : 66318442.9011, Test Accuracy : 48.08
#
# [261] Train Loss: 18045734.1078, Train Accuracy: 49.04
# [261] Test Loss : 82991953.5824, Test Accuracy : 47.53
#
# [262] Train Loss: 17471482.389, Train Accuracy: 48.95
# [262] Test Loss : 71183500.6593, Test Accuracy : 46.15
#
# [263] Train Loss: 17970807.2329, Train Accuracy: 49.04
# [263] Test Loss : 69171790.7692, Test Accuracy : 51.92
#
# [264] Train Loss: 21015913.9068, Train Accuracy: 49.59
# [264] Test Loss : 73077152.3516, Test Accuracy : 49.45
#
# [265] Train Loss: 19167576.1388, Train Accuracy: 48.49
# [265] Test Loss : 73778417.9341, Test Accuracy : 51.92
#
# [266] Train Loss: 17621760.7014, Train Accuracy: 52.42
# [266] Test Loss : 76773027.1648, Test Accuracy : 46.7
#
# [267] Train Loss: 16781066.9881, Train Accuracy: 52.42
# [267] Test Loss : 60325274.7253, Test Accuracy : 56.59
#
# [268] Train Loss: 17478722.3963, Train Accuracy: 52.15
# [268] Test Loss : 70088760.2637, Test Accuracy : 55.49
#
# [269] Train Loss: 17953031.7151, Train Accuracy: 49.68
# [269] Test Loss : 60904493.011, Test Accuracy : 53.57
#
# [270] Train Loss: 18624450.2795, Train Accuracy: 51.78
# [270] Test Loss : 75808340.3956, Test Accuracy : 47.8
#
# [271] Train Loss: 18248646.9553, Train Accuracy: 50.68
# [271] Test Loss : 76378460.8352, Test Accuracy : 50.0
#
# [272] Train Loss: 18526208.0, Train Accuracy: 50.78
# [272] Test Loss : 70025637.978, Test Accuracy : 51.37
#
# [273] Train Loss: 19217483.7479, Train Accuracy: 49.77
# [273] Test Loss : 75946484.7473, Test Accuracy : 46.15
#
# [274] Train Loss: 16161390.8164, Train Accuracy: 50.32
# [274] Test Loss : 69999925.4505, Test Accuracy : 53.57
#
# [275] Train Loss: 18157495.0575, Train Accuracy: 52.24
# [275] Test Loss : 80558276.9231, Test Accuracy : 49.45
#
# [276] Train Loss: 18431057.3589, Train Accuracy: 51.23
# [276] Test Loss : 76455165.1868, Test Accuracy : 46.98
#
# [277] Train Loss: 19431601.6804, Train Accuracy: 49.41
# [277] Test Loss : 81725012.3956, Test Accuracy : 49.73
#
# [278] Train Loss: 16687861.4795, Train Accuracy: 53.06
# [278] Test Loss : 72911202.4615, Test Accuracy : 49.18
#
# [279] Train Loss: 15776091.8795, Train Accuracy: 50.32
# [279] Test Loss : 62190366.9451, Test Accuracy : 56.32
#
# [280] Train Loss: 18651480.1388, Train Accuracy: 50.5
# [280] Test Loss : 65986064.8791, Test Accuracy : 51.37
#
# [281] Train Loss: 20133257.7023, Train Accuracy: 52.51
# [281] Test Loss : 74969864.4396, Test Accuracy : 50.0
#
# [282] Train Loss: 18138516.9242, Train Accuracy: 50.68
# [282] Test Loss : 76930402.4615, Test Accuracy : 52.47
#
# [283] Train Loss: 19021790.3342, Train Accuracy: 50.5
# [283] Test Loss : 74842612.7473, Test Accuracy : 51.65
#
# [284] Train Loss: 20087992.2265, Train Accuracy: 50.14
# [284] Test Loss : 67475996.1319, Test Accuracy : 52.2
#
# [285] Train Loss: 17138743.1744, Train Accuracy: 49.04
# [285] Test Loss : 81966226.2857, Test Accuracy : 46.7
#
# [286] Train Loss: 19809875.6968, Train Accuracy: 50.41
# [286] Test Loss : 70146458.7253, Test Accuracy : 49.45
#
# [287] Train Loss: 19579850.6959, Train Accuracy: 50.32
# [287] Test Loss : 76270034.989, Test Accuracy : 49.73
#
# [288] Train Loss: 17418997.4795, Train Accuracy: 51.23
# [288] Test Loss : 67287681.4066, Test Accuracy : 54.4
#
# [289] Train Loss: 19094684.1717, Train Accuracy: 50.32
# [289] Test Loss : 73398035.6923, Test Accuracy : 48.08
#
# [290] Train Loss: 18306443.5726, Train Accuracy: 49.68
# [290] Test Loss : 66952231.3846, Test Accuracy : 47.8
#
# [291] Train Loss: 20726107.8795, Train Accuracy: 48.58
# [291] Test Loss : 73597012.3956, Test Accuracy : 50.55
#
# [292] Train Loss: 17319277.6475, Train Accuracy: 49.13
# [292] Test Loss : 64467934.2418, Test Accuracy : 53.02
#
# [293] Train Loss: 19484181.9763, Train Accuracy: 49.68
# [293] Test Loss : 78369189.978, Test Accuracy : 48.35
#
# [294] Train Loss: 17573699.0977, Train Accuracy: 47.85
# [294] Test Loss : 75616554.1978, Test Accuracy : 48.08
#
# [295] Train Loss: 18967004.9315, Train Accuracy: 49.86
# [295] Test Loss : 76740186.022, Test Accuracy : 50.0
#
# [296] Train Loss: 17746511.021, Train Accuracy: 50.68
# [296] Test Loss : 64622637.011, Test Accuracy : 52.47
#
# [297] Train Loss: 19948969.4977, Train Accuracy: 51.96
# [297] Test Loss : 62388927.2967, Test Accuracy : 50.55
#
# [298] Train Loss: 18354200.3142, Train Accuracy: 52.05
# [298] Test Loss : 81150244.5714, Test Accuracy : 47.53
#
# [299] Train Loss: 18938387.1708, Train Accuracy: 49.59
# [299] Test Loss : 74745276.4835, Test Accuracy : 46.7
#
# [300] Train Loss: 19128998.926, Train Accuracy: 51.32
# [300] Test Loss : 67747378.6374, Test Accuracy : 53.3

# %%
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous*factor + point*(1.-factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
epochs = np.arange(1, EPOCHS+1)
train_loss = smooth_curve(np.array(history['train_loss']))
test_loss = smooth_curve(np.array(history['test_loss']))
train_acc = smooth_curve(np.array(history['train_acc']))
test_acc = smooth_curve(np.array(history['test_acc']))

plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
plt.plot(epochs, train_loss, "b", label="train loss")
plt.plot(epochs, test_loss, "r", label="test loss")
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.plot(epochs, train_acc, "b", label="train acc")
plt.plot(epochs, test_acc, "r", label="test acc")
plt.legend(loc='best')
